# %% [markdown]
# # Booleans , True False

# %%
issubclass(bool,int)
# Out:
# True

# %% [markdown]
# ### the issubclass method checks If a class is an inheritance of another

# %%
isinstance(True,bool)
isinstance(True,int)
# Out:
# True

# %% [markdown]
# ### method do check If a object is an instance, or subclass instance of a specific class

# %%
a =  True
b =  False
c = a
d = True
e = False
f = e
g = a
h = 3<2
i = True or False

# %%
print(hex(id(a)))
print(hex(id(b)))
print(hex(id(c)))
print(hex(id(d)))
print(hex(id(e)))
print(hex(id(f)))
print(hex(id(g)))
print(hex(id(h)))
print(hex(id(i)))
# Out:
# 0xa29360
# 0xa29380
# 0xa29360
# 0xa29360
# 0xa29380
# 0xa29380
# 0xa29360
# 0xa29380
# 0xa29360

# %% [markdown]
# ### equal booelan values share same memory adress, they are basiclly slington objects

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
hex(id(int(True)))
# Out:
# '0xb359a8'

# %%
hex(id(int(False)))
# Out:
# '0xb35988'

# %% [markdown]
# ### while booleans are inherited istances of the int data type, they are not the same object, aka they are not stored in the same memory adress, 0 and 1 and stored in different memeory adresses from True and False

# %%
print(True == 1)
print(True is int(1))
# Out:
# True
# False

# %%
True > False # since True is 1 and False is 0
# Out:
# True

# %%
True + True + True
# Out:
# 3

# %% [markdown]
# ### we can the truth value of an object:

# %%
print(bool(0),
bool(1),
bool(2),
bool(-1)
)
# Out:
# False True True True

# %% [markdown]
# ### not only integers, but all objects have a truth value, called truthiness!
# ### by default, objects have an association with truth boolean value, there are exception, and we can costumize It as well

# %%
bool(None), bool(()), bool([]) ,      bool({})            , bool([1,2,3])
#None value, empty tuple, empty list  ,empty dict/set
# Out:
# (False, False, False, False, True)

# %% [markdown]
# ### they all return a falsely bool value by default

# %% [markdown]
# ### can use __bool__ or __len__ to change truthiness association

# %%
bool(0),(0).__bool__(),bool(()),bool(""),bool([]),bool({}),bool(set())
# Out:
# (False, False, False, False, False, False, False)

# %%
bool(None)
# Out:
# False

# %% [markdown]
# ### the bool of an object that has a lengh of 0 is false , None objects always truth to False

# %%
a = [3,2,1]
if a is not None and len(a)>0:
    print("list exists")
else :
    print("list doesnt exist")
# Out:
# list exists

# %%
if a:
    print("list exists")
else :
    print("list doesnt exist")
# Out:
# list exists

# %% [markdown]
# ### both lines : if a is not None and len(a)>0:     and     if a:      do the same thing
