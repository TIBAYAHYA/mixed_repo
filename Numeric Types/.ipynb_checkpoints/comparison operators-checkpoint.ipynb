# %%
from decimal import Decimal
from fractions import Fraction
import math

# %%
Decimal("0.125") == 0.125
# Out:
# True

# %%
Decimal("0.125") == Fraction(1,8)
# Out:
# True

# %%
Fraction(1,8) < math.pi
# Out:
# True

# %% [markdown]
# ### this looks weird but makes total sense from python's persepective

# %%
a = 3
b = 5
c = 6
print(a == b == c) # equivalant to a == b and a == c
print( a > b < c) # equivalant to a > b and a < c
# Out:
# False
# False

# %% [markdown]
# ### we can go even further with It

# %%
a > c < b < a == c > d # equivalant to a > c and c < b and b < a and a == c and c > d
# Out:
# False

# %% [markdown]
# ### the circuting on and method stops whenever we find a false,
# ### as opposed to the or method, where the circuting stops whenever a False bool is found

# %%
1 is 1
# Out:
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# /tmp/ipykernel_11533/1728060598.py:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   1 is 1
# True

# %% [markdown]
# ### of course object that get stored on multiple memeory addresses do not have same memory address

# %%
[1,2,3,4] is [1,2,3,4]
# Out:
# False

# %%
keyer = {"key1":1, "key2": 2 , "key3": 3}
"key1" in keyer
# Out:
# True

# %% [markdown]
# ### however the in method only checks for the dictionary's keys

# %%
1 in keyer
# Out:
# False

# %%
1 == True
# Out:
# True

# %% [markdown]
# ### yeah no way bro, True is just equal to 1

# %%
"A" < "a"
# Out:
# True

# %% [markdown]
# ## how can we put circuting to a use?

# %%
# look 
# at 
# this
min_age = 0
max_age = 100
list_of_candidates = {"Bob":200,"Camel":30,"Bastard":50,"Mahmoud":99,"Fred":-1}
for age in list_of_candidates.values():
    if min_age > age <max_age:
        print(f"{list_of_candidates[age]}")
# Out:
# 200
# 30
# 50
# 99
