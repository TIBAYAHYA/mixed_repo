# %% [markdown]
# ## complex numbers are numbers that contain both an imaginary and real part

# %%
# two ways (maybe more) can be used to create complex numbers
a = 1 + 3j
b = complex(1,3) # rectangular coordinates

# %%
print(type(a))
print(type(b))
# Out:
# <class 'complex'>
# <class 'complex'>

# %%
help(complex)
# Out:
# Help on class complex in module builtins:
#
# class complex(object)
#  |  complex(real=0, imag=0)
#  |
#  |  Create a complex number from a real part and an optional imaginary part.
#  |
#  |  This is equivalent to (real + imag*1j) where imag defaults to 0.
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __bool__(self, /)
#  |      True if self else False
#  |
#  |  __complex__(self, /)
#  |      Convert this value to exact type complex.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Convert to a string according to format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getnewargs__(self, /)
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __hash__(self, /)
# ...

# %% [markdown]
# ### methods that return real/imaginary part of a complex number, or the conjugate,(conjugate gives the entire thing huh?)

# %%
print(a.real,a.imag)
print(b.real,b.imag)
print(a.conjugate(),b.conjugate())
# Out:
# 1.0 3.0
# 1.0 3.0
# (1-3j) (1-3j)

# %% [markdown]
# ### complex numbers are stored as floats( what the fuck ) , and so they are treated the same way, same precision

# %% [markdown]
# ### although they
# ### we can also use arithmetic operators and/or mix complex numbers:

# %%
print(a)
print(a + b)
print(a +1)
print(a + 1j)
print(a * 1j)
print(a/b)
print(a**b)
# Out:
# (1+3j)
# (2+6j)
# (2+3j)
# (1+4j)
# (-3+1j)
# (1+0j)
# (-0.000705958476895637-0.07457950287906594j)

# %%
print(a // 3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 print(a // 3)
#       2 print(a % 2)
#
# TypeError: unsupported operand type(s) for //: 'complex' and 'int'

# %%
print(a % 2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 print(a % 2)
#
# TypeError: unsupported operand type(s) for %: 'complex' and 'int'

# %% [markdown]
# ### but we cannot use the floor division and modulo modules on complex numbers

# %% [markdown]
# #### alot of other stuff work or doesnt work, figure It out for yourself

# %% [markdown]
# ## and of course, floats are problems when It comes to precision, and so that means:

# %%
a = 0.1j
print(f" a = {format(a.imag,".25f")}")
print(f" 0.3j = {format(0.3j.imag, ".25f")}")
0.3j.imag == a.imag*3
# Out:
#  a = 0.1000000000000000055511151
#  0.3j = 0.2999999999999999888977698
# False

# %%
import cmath
import math
cmath.pi
# Out:
# 3.141592653589793

# %%
math.sqrt(1)
# Out:
# 1.0

# %%
a = 1 + 1j
math.sqrt(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 a = 1 + 1j
# ----> 2 math.sqrt(a)
#
# TypeError: must be real number, not complex

# %%
cmath.sqrt(a)
# Out:
# (1.09868411346781+0.45508986056222733j)

# %% [markdown]
# ### we need the cmath library to use advanced operations on complex numbers

# %% [markdown]
# ### polar to rectangular and opposite

# %%
abs(a)
# Out:
# 1.4142135623730951

# %%
cmath.rect(math.sqrt(2), math.pi/4)
# Out:
# (1.0000000000000002+1j)
