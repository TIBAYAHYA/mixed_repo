# %%
from fractions import Fraction
Fraction(6,3)
# Out:
# Fraction(2, 1)

# %%
Fraction(6/3) # same thing as above
# Out:
# Fraction(2, 1)

# %%
Fraction()  # default value is Fraction(numerator = 0, denominator = 1 )
# Out:
# Fraction(0, 1)

# %%
Fraction(1,2) + Fraction(1,6)
# Out:
# Fraction(2, 3)

# %%
Fraction(1,3)

# %%
x = Fraction(9,6)

# %%
x.numerator
# Out:
# 3

# %%
x.denominator
# Out:
# 2

# %% [markdown]
# #### float objects can be written as fractions

# %%
Fraction(3.75)
# Out:
# Fraction(15, 4)

# %%
Fraction(3.74)
# Out:
# Fraction(2105432825795707, 562949953421312)

# %% [markdown]
# #### This can be a helpful way to better represent floats, since python interpreter, and generally any interpreter at all has a limited precision when It comes to floats

# %%
Fraction(355,113)
# Out:
# Fraction(355, 113)

# %%
355/113
# Out:
# 3.1415929203539825

# %% [markdown]
# ## The fraction method can also take strings as parameters

# %%
Fraction("10/2")
# Out:
# Fraction(5, 1)

# %%
Fraction("10,2")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 Fraction("10,2")
#
# File /usr/lib/python3.12/fractions.py:239, in Fraction.__new__(cls, numerator, denominator)
#     237 m = _RATIONAL_FORMAT.match(numerator)
#     238 if m is None:
# --> 239     raise ValueError('Invalid literal for Fraction: %r' %
#     240                      numerator)
#     241 numerator = int(m.group('num') or '0')
#     242 denom = m.group('denom')
#
# ValueError: Invalid literal for Fraction: '10,2'

# %% [markdown]
# ### Although,for some reason the camma seperator on strings doesnt get interpreted as expected

# %%
import math
x = Fraction(math.pi) 
x  # pi is not rational, however the pi value stored in our computer has a limit, and therefor It can be expressed as a fraction
# Out:
# Fraction(884279719003555, 281474976710656)

# %% [markdown]
# ### we can limit the value of denominator,
# ### the method below means the closest fraction of x where the denominator doesnt exceed 10

# %%
x.limit_denominator(10)
# Out:
# Fraction(22, 7)

# %%
22/7
# Out:
# 3.142857142857143

# %%
x.limit_denominator(100)
# Out:
# Fraction(311, 99)

# %%
311/99
# Out:
# 3.1414141414141414

# %% [markdown]
# ### we can go further and further, and the further we go, the closer we get to real pi value

# %%
x.limit_denominator(10000000)
# Out:
# Fraction(5419351, 1725033)

# %%
from fractions import Fraction
help(Fraction)
# Out:
# Help on class Fraction in module fractions:
#
# class Fraction(numbers.Rational)
#  |  Fraction(numerator=0, denominator=None)
#  |
#  |  This class implements rational numbers.
#  |
#  |  In the two-argument form of the constructor, Fraction(8, 6) will
#  |  produce a rational number equivalent to 4/3. Both arguments must
#  |  be Rational. The numerator defaults to 0 and the denominator
#  |  defaults to 1 so that Fraction(3) == 3 and Fraction() == 0.
#  |
#  |  Fractions can also be constructed from:
#  |
#  |    - numeric strings similar to those accepted by the
#  |      float constructor (for example, '-2.3' or '1e10')
#  |
#  |    - strings of the form '123/456'
#  |
#  |    - float and Decimal instances
#  |
#  |    - other Rational instances (including integers)
#  |
#  |  Method resolution order:
#  |      Fraction
#  |      numbers.Rational
#  |      numbers.Real
#  |      numbers.Complex
#  |      numbers.Number
#  |      builtins.object
#  |
#  |  Methods defined here:
# ...

# %% [markdown]
# #### Python will prefer putting negatif sign over numerator

# %%
Fraction(1,-4)
# Out:
# Fraction(-1, 4)

# %%
format(0.3,"0.25f")
# Out:
# '0.2999999999999999888977698'

# %%
a = Fraction(0.3)
a
# Out:
# Fraction(5404319552844595, 18014398509481984)

# %%
a.limit_denominator(10) # we limit the value denominator can take, and that allows us to get more precise with It
# Out:
# Fraction(3, 10)
